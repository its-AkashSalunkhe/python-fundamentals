# %% [markdown]
# # Binary Numbers

# %%
bin(25)
# Out:
# '0b11001'

# %%
int(11001)
# Out:
# 11001

# %%
int(0b11001)
# Out:
# 25

# %%
bin(34)
# Out:
# '0b100010'

# %% [markdown]
# # Octal Numbers

# %%
oct(23)
# Out:
# '0o27'

# %%
oct(25)
# Out:
# '0o31'

# %%
int(0o31)
# Out:
# 25

# %% [markdown]
# # Hexadecimal and Decimal Numbers

# %%
hex(2)
# Out:
# '0x2'

# %%
hex(39)
# Out:
# '0x27'

# %%
hex(25)
# Out:
# '0x19'

# %%
int(0x19)
# Out:
# 25
