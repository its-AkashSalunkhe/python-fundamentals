# %% [markdown]
# # WORKING WITH NUMBERS

# %%
4+65
# Out:
# 69

# %%
4-5+7/4*5
# Out:
# 7.75

# %%
a = 10
b = 20

# %%
int.__add__(a,b)
# Out:
# 30

# %%
int.__add__(a,b)
# Out:
# 30

# %%
int.__sub__(a,b)
# Out:
# -10

# %%
int.__mul__(a,b)
# Out:
# 200

# %%
c = 30

# %%
result = a+b+c

# %%
print(result)
# Out:
# 60

# %%
c = 23
id(c)
# Out:
# 140724510041704

# %% [markdown]
# # WORKING WITH STRINGS

# %%
"AKASH"
# Out:
# 'AKASH'

# %%
'AKASH'
# Out:
# 'AKASH'

# %%
'''AKASH
        SALUNKHE'''
# Out:
# 'AKASH\n        SALUNKHE'

# %%
a = "Akash"
b = "Salunkhe"

# %%
str.__add__(a,b)
# Out:
# 'AkashSalunkhe'

# %% [markdown]
# # Float

# %%
a = 3423.3242

# %%
a
# Out:
# 3423.3242

# %%
a = 10.34e2

# %%
a
# Out:
# 1034.0

# %%
b = 324.423234e4
b
# Out:
# 3244232.34

# %% [markdown]
# # Complex ( Datatype )

# %%
a = 10+20j
a
# Out:
# (10+20j)

# %%
type(a)
# Out:
# complex

# %%
b = 30+40j
b
# Out:
# (30+40j)

# %%
a + b
# Out:
# (40+60j)
