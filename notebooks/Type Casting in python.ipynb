# %% [markdown]
# # Type Casting

# %%
int(233.34)
# Out:
# 233

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int("3434343")
# Out:
# 3434343

# %%
a = 30
b = 30

id(a)
# Out:
# 140724510041928

# %%
id(b)
# Out:
# 140724510041928

# %%
# means that both variables a and b pointing to same value 20

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False, False)
# Out:
# 0j
